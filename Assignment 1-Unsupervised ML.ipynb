# %% [markdown]
# # Machine Learning Assignment- PCA

# %% [markdown]
# In this project we will examine the first 2 principal components of X. These components contain lots of information about our data set. Create a scatter plot with each of the 150 rows of X projected onto the first two principal components. In other words, the horizontal axis should be first principal component, the vertical axis should be second principal component.
# In this project, we will run PCA on a real data set, and interpret the output.<br>
#
#
# Dataset: The given data sets consists of 3 different types of irises’ (Setosa, Versicolour, and Virginica) petal and sepal length, stored in a 150x4 numpy.ndarray.The rows being the samples and the columns being: Sepal Length, Sepal Width, Petal Length and Petal Width. The dataset is already available in sklearn.

# %% [markdown]
# ### Import the necessary libraries and modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from string import ascii_letters
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split 
from matplotlib.colors import ListedColormap 
from sklearn.metrics import confusion_matrix 
import warnings

# %% [markdown]
# ### Question 1
#
# Using Pandas DataFrame load the iris data.
#
# *This function should return a DataFrame of shape `(150, 5)`.*

# %%
def answer_one():
  "your code goes here"
  return 

answer_one()

# %% [markdown]
# ### Question 2
#
# How many features does the iris dataset have?
#
# *This function should return `feature names`.*

# %%
def answer_two():
  "your code goes here"
  return 


answer_two()

# %% [markdown]
# ### Question 3
#
# Find the correlation of dimensions of the dataset.
#
# *This function should return a DataFrame of shape `(5, 5)`.* Use corr() method

# %%
def answer_three():
  "your code goes here"
  return 


answer_three()

# %% [markdown]
# ### Question 4
# Split the DataFrame into `X` (the data) and `y` (the labels).
#
# *This function should return a tuple of length 2:* `(X, y)`*, where*
# * `X`*, a pandas DataFrame, has shape* `(150, 4)`
# * `y`*, a pandas Series, has shape* `(150,)`.

# %%
def answer_four():
  "your code goes here"
  return 


answer_four()

# %% [markdown]
# ### Question 5
#
# Standardize the data by applying `Feature Scaling` on these features (X) using `StandardScaler`.
#
# The function should return scaled features, with shape (150, 4).

# %%
def answer_five():
  "your code goes here"
  return 


answer_five()

# %% [markdown]
# ### Question 6
#
# Project the dataset which is 4 dimensional into 2 dimensions using `PCA`.
#
# Plot the 2 principal components with maximum variance

# %%
def answer_six():
  "your code goes here"
  return 


answer_six()
